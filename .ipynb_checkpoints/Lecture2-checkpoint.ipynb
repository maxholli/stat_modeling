# %% [markdown]
# ## Lecture 2
#
# Densities, likelihoods and MLEs

# %%
import numpy as np
from scipy import signal
import scipy.stats as stats
import scipy
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# normal density example
mu = 0
sd = 1

xgrid = np.linspace(-5, 5, 101)
dist = stats.norm(mu, sd)
xdensity = dist.pdf(xgrid)
plt.plot(xgrid, xdensity)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## random sample -- of size n from Normal
n = 10
X = dist.rvs(n)
print(X)

## add sampled points to the density plot
plt.plot(xgrid, xdensity)
plt.scatter(X, np.zeros(10))
plt.show()
# Out:
# [-0.44153582  0.01085897  0.29104991  0.20754232 -0.28808284  1.69395345
#   1.38834326  0.33344269 -0.53500304 -1.96345227]
# <img src="data:image/png;base64,..." width="640">

# %%
## Likelihood of mu (addumes unknown mu, known sd)
def likeNorm(m):
    dist = stats.norm(m, sd)
    return np.exp(np.sum(dist.logpdf(X)))

def negLogLikeNorm(m):
    dist = stats.norm(m, sd)
    return -1 * np.sum(dist.logpdf(X))

def testGlobal(m):
    return np.sum(X) + m

# %%
test_ln = list(map(likeNorm, xgrid))
test_nlln = list(map(negLogLikeNorm, xgrid))
plt.plot(xgrid, test_ln, xgrid, test_nlln)
plt.legend(('Likelihood', 'Negative Log Likelihood'),
           loc='upper right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Above: the likelihood has a normal shape. you have to zoom in

# %%
### Find the MLE: Optimization
nrep = 100
MLEsO = np.zeros(nrep)
MLEsN = np.zeros(nrep)
MLEvO = np.zeros(nrep)
MLEvN = np.zeros(nrep)

for i in range(nrep):
    n = 10
    dist = stats.norm(mu, sd)
    X = dist.rvs(n)
    #print(X)
    #print(testGlobal(1))
    ## tempOptim = optim(0.01,neglogLikNorm,method='L-BFGS-B',lower=-10,upper=10,hessian=TRUE)
    bnds = 
    tempOptim = scipy.optimize.minimize(negLogLikeNorm, [0.01], method='L-BFGS-B', bounds=((-10,10)) )
    ## tempNLM = nlm(neglogLikNorm,0.01,hessian=TRUE)
    #tempNLM = nlm()
    
    MLEsO[i] = tempOptim.x##= tempOptim$par
    #MLEsN[i] = tempNLM$estimate
    MLEvO[i] = 1/tempOptim.hess_inv
    #MLEvN[i] = 1/tempNLM$hessian
    
print(MLEsO)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-db963a88a06c> in <module>()
#      13     #print(testGlobal(1))
#      14     ## tempOptim = optim(0.01,neglogLikNorm,method='L-BFGS-B',lower=-10,upper=10,hessian=TRUE)
# ---> 15     tempOptim = scipy.optimize.minimize(negLogLikeNorm, [0.01], method='L-BFGS-B', bounds=((-10,10)) )
#      16     ## tempNLM = nlm(neglogLikNorm,0.01,hessian=TRUE)
#      17     #tempNLM = nlm()
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     601     elif meth == 'l-bfgs-b':
#     602         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 603                                 callback=callback, **options)
#     604     elif meth == 'tnc':
#     605         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     265         bounds = [(None, None)] * n
#     266     if len(bounds) != n:
# --> 267         raise ValueError('length of x0 != length of bounds')
#     268     # unbounded variables must use None, not +-inf, for optimizer to work properly
#     269     bounds = [(None if l == -np.inf else l, None if u == np.inf else u) for l, u in bounds]
#
# ValueError: length of x0 != length of bounds

# %%
list(t1)
# Out:
# [1, 4, 9, 16, 25]

# %%
fun = lambda x: (x[0] - 1)**2 + (x[1] - 2.5)**2
t_a = [1, 1]
print(fun(t_a))
con
# Out:
# 2.25

# %%
fun = lambda x: x[0]**2 - 2*x[0]
x15 = [14]
bnds = ((-10, 10))

results = scipy.optimize.minimize(fun, x15, method='L-BFGS-B', bounds=bnds)
print(results.x)

x = np.linspace(-3, 5, 100)
#print(fun(x))
plt.plot(x, fun(x))
plt.plot(results.x, fun(results.x), 'ro')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-8c3c5ac5012f> in <module>()
#       3 bnds = ((-10, 10))
#       4
# ----> 5 results = scipy.optimize.minimize(fun, x15, method='L-BFGS-B', bounds=bnds)
#       6 print(results.x)
#       7
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     601     elif meth == 'l-bfgs-b':
#     602         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 603                                 callback=callback, **options)
#     604     elif meth == 'tnc':
#     605         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     265         bounds = [(None, None)] * n
#     266     if len(bounds) != n:
# --> 267         raise ValueError('length of x0 != length of bounds')
#     268     # unbounded variables must use None, not +-inf, for optimizer to work properly
#     269     bounds = [(None if l == -np.inf else l, None if u == np.inf else u) for l, u in bounds]
#
# ValueError: length of x0 != length of bounds
